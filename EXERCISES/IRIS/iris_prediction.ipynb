# %% [markdown]
# ## PROBLEM DESCRIPTION
#
# The iris flower has 3 species: setosa, versicolor, and virginica. Each species has different characteristics based on the measurements of their petals and sepals.
#
# <img src="iris.png" width="500"/>
#
# We have several feature data of 150 iris flowers:
# * Sepal length in cm
# * Sepal width in cm
# * Petal length in cm
# * Petal width in cm
# * Species: setosa, versicolor, virginica
#
# These data can be found in the files `iris_features.csv`and `iris_labels.csv`. The CSV stands for "comma-separated values": the data is stored in plain text where each value is separated by a comma.
#
# Part of the data is shown below:
#
# <img src="data.png" width="350"/>
#
# The figure belowe shows a scatter plot of the iris flowers based on sepal length and sepal width, colored by species.
#
# <img src="plot.png" width="500"/>

# %% [markdown]
# ## EXERCISE GOAL
#
# Suppose we have a new iris flower with the following measurements:
# * Sepal length: 5.0 cm
# * Sepal width: 2.5 cm
#
# This new flower is represented by the black point shown in the figure below:
#
# <center><img src="punt.png" width="750"/></center>
#
# Using the techniques we discussed in the previous 2 sessions, we want to predict the species of this new iris flower based on the existing data.

# %% [markdown]
# ## Work Flow
#
# 1. Import the features and labels from the CSV files.
#     * Skip the header row.
#     * Remove newline characters.
#     * Split the feature values by commas.
#     * Convert the feature values to floats.
# 2. The formula for Euclidean distance between two points ($x_1$, $y_1$) and ($x_2$, $y_2$) is:
#
#     $$
#     d = \sqrt{(x_1 - x_2)^2 + (y_1 - y_2)^2}
#     $$
#
#     Calculate the Euclidean distance between the given sepal length and width and all other flowers in the dataset. Save these distances in a list `distances`.
# 3. Find the smallest distance and return the species of that flower as the predicted species.

# %% [markdown]
# ## SOLUTION
#
# 1. Import the features and labels from the CSV files. Skip the header row.

# %%
# (a) Read iris features from iris_features.csv


# Skip the header


# Process each line to convert it into a list of floats


# (b) Read iris labels from iris_labels.csv


# Skip the header


# Process each label to remove any trailing newline characters
# Out:
# Predicted species: versicolor

# %% [markdown]
# 2. Calculate the Euclidean distance between the given sepal length and width and all other flowers in the dataset. Save these distances in a list `distances`.

# %%
# # Define a sepal length and width
# sep_len = 5.0
# sep_wid = 2.5

# # Calculate the Euclidean distances
# # (a) create an empty list distances
# distances = []
# # (b) loop over each row in features

# Define a sepal length and width
sep_len = 5.0
sep_wid = 2.5

# Calculate the Euclidean distances
# (a) create an empty list distances
distances = []

# (b) loop over each row in features
for row in features:
    x1 = row[0]   # sepal length
    y1 = row[1]   # sepal width

    d = ((x1 - sep_len) ** 2 + (y1 - sep_wid) ** 2) ** 0.5
    distances.append(d)
    
print(distances)
# Out:
# [1.004987562112089, 0.5099019513592784, 0.761577310586391, 0.7211102550927981, 1.1, 1.4560219778561037, 0.9848857801796105, 0.8999999999999999, 0.7211102550927976, 0.608276253029822, 1.264911064067352, 0.9219544457292886, 0.5385164807134505, 0.8602325267042628, 1.7, 2.024845673131659, 1.4560219778561037, 1.004987562112089, 1.4764823060233399, 1.3038404810405295, 0.9848857801796105, 1.2041594578792296, 1.1704699910719627, 0.8062257748298547, 0.9219544457292886, 0.5, 0.8999999999999999, 1.019803902718557, 0.9219544457292886, 0.761577310586391, 0.632455532033676, 0.9848857801796105, 1.6124515496597096, 1.7720045146669352, 0.608276253029822, 0.7000000000000002, 1.118033988749895, 1.104536101718726, 0.7810249675906652, 0.9055385138137415, 1.0, 0.5385164807134505, 0.9219544457292886, 1.0, 1.3038404810405295, 0.5385164807134505, 1.3038404810405295, 0.8062257748298554, 1.2369316876852983, 0.7999999999999998, 2.118962010041709, 1.5652475842498532, 1.9924858845171278, 0.5385164807134505, 1.5297058540778354, 0.761577310586391, 1.5264337522473745, 0.1414213562373093, 1.6492422502470638, 0.2828427124746193, 0.5, 1.0295630140987002, 1.0440306508910548, 1.1704699910719623, 0.7211102550927976, 1.8027756377319948, 0.7810249675906652, 0.8246211251235319, 1.2369316876852983, 0.5999999999999996, 1.1401754250991385, 1.1401754250991376, 1.2999999999999998, 1.1401754250991376, 1.456021977856104, 1.6763054614240207, 1.8248287590894656, 1.7720045146669352, 1.0770329614269007, 0.7071067811865478, 0.5099019513592785, 0.5099019513592785, 0.8246211251235319, 1.019803902718557, 0.6403124237432851, 1.345362404707371, 1.8027756377319948, 1.3152946437965904, 0.7810249675906652, 0.5, 0.5099019513592785, 1.2083045973594568, 0.8062257748298548, 0.20000000000000018, 0.6324555320336757, 0.8602325267042628, 0.806225774829855, 1.2649110640673518, 0.09999999999999964, 0.761577310586391, 1.5264337522473745, 0.8246211251235319, 2.15870331449229, 1.360147050873544, 1.5811388300841898, 2.647640458974745, 0.09999999999999964, 2.33452350598575, 1.7000000000000002, 2.459674775249769, 1.6552945357246849, 1.4142135623730956, 1.8681541692269403, 0.7000000000000002, 0.8544003745317529, 1.5652475842498532, 1.5811388300841898, 2.9966648127543394, 2.701851217221259, 1.0440306508910548, 2.024845673131659, 0.6708203932499366, 2.716615541441225, 1.3152946437965904, 1.8788294228055937, 2.3086792761230392, 1.2369316876852983, 1.2083045973594568, 1.4317821063276357, 2.2561028345356955, 2.418677324489565, 3.178049716414141, 1.4317821063276357, 1.334166406412633, 1.1045361017187258, 2.7459060435491964, 1.5811388300841893, 1.523154621172782, 1.118033988749895, 1.9924858845171278, 1.8027756377319948, 1.9924858845171278, 0.8246211251235319, 1.9313207915827966, 1.8788294228055937, 1.7720045146669352, 1.2999999999999998, 1.5811388300841898, 1.5, 1.0295630140987002]

# %% [markdown]
# 3. Find the smallest distance and return the species of that flower as the predicted species.

# %%
# # Find the nearest neighbor: ie the minimum distance and its index

# print("Minimum distance:")
# print("Index of nearest neighbor:")

# # Final step: predict the species of the new iris sample based on the nearest neighbor


# # Step 4: Print the predicted species
# print("Predicted species:")

# Find the nearest neighbor: ie the minimum distance and its index
min_distance = min(distances)
min_index = distances.index(min_distance)

print("Minimum distance:", min_distance)
print()

print("Index of nearest neighbor:", min_index)
print()

# Final step: predict the species of the new iris sample based on the nearest neighbor
predicted_species = labels[min_index]

# Step 4: Print the predicted species
print("Predicted species:", predicted_species)
# Out:
# Minimum distance: 0.09999999999999964
#
# Index of nearest neighbor: 98
#
# Predicted species: versicolor

# %% [markdown]
# ## SOLUTION with Numpy
#
# Using the numpy module, we can simplify the calculations and make the code more efficient.

# %% [markdown]
# 1. Import the features and labels from the CSV files.

# %%
import numpy as np

# %% [markdown]
# 2. The formula for Euclidean distance between two points ($x_1$, $y_1$) and ($x_2$, $y_2$) is:
#
#     $$
#     d = \sqrt{(x_1 - x_2)^2 + (y_1 - y_2)^2}
#     $$
#
#     Calculate the Euclidean distance between the given sepal length and width and all other flowers in the dataset.

# %% [markdown]
# 3. Find the smallest distance and return the species of that flower as the predicted species.

# %% [markdown]
# ### Extension
# Suppose we want to use all four features (sepal length, sepal width, petal length, petal width) to calculate the Euclidean distance. We have to modify the code accordingly. The only change needed is in the distance calculation step.
#
# The formula for Euclidean distance between two points ($x_1$, $y_1$, $z_1$, $w_1$) and ($x_2$, $y_2$, $z_2$, $w_2$  ) becomes:
#
# $$
# d = \sqrt{(x_1 - x_2)^2 + (y_1 - y_2)^2 + (z_1 - z_2)^2 + (w_1 - w_2)^2}
# $$
#
# We can implement this in the code by considering all four features when calculating the distances. The rest of the code remains the same.

# %%
sep_len = 5.0
sep_wid = 2.5
pet_len = 3.5
pet_wid = 1.0
